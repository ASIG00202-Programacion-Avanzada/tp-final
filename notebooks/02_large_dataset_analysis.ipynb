# %%
# Análisis de Datasets Grandes - Properati Argentina

Este notebook está diseñado para manejar datasets grandes de Properati de manera eficiente, usando técnicas de muestreo estratificado y optimización de memoria.

# %%
# Importar librerías necesarias
import sys
from pathlib import Path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# Agregar src al path
sys.path.append(str(Path.cwd().parent / "src"))

from large_data_handler import LargeDataHandler
from config import *

# Configurar visualizaciones
plt.style.use('seaborn-v0_8')
sns.set_palette("husl")

# Inicializar manejador de datos grandes
handler = LargeDataHandler(chunk_size=10000)
